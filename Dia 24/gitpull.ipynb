# %% [markdown]
# ## Transferência do remoto para o local com git pull completa

# %%
print('É muito importante antes de começar a trabalhar com seu repositório dar um git pull.')
# Out:
# É muito importante antes de começar a trabalhar com seu repositório dar um git pull.
