# %% [markdown]
# oio

# %%
# importando bibliotecas
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.cofecon.org.br/2024/10/30/cofecon-realiza-oficina-sobre-inteligencia-artificial-para-economistas/'

response = requests.get(url)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    title = soup.title.string
    print(f'Título da página: {title}')
    
    links = soup.find_all('a')
    
    for i in links:
        print(f'Link encontrado: {i.get('href')}')

else:
    print(f'Falha ao acessar a página {url}: {response.status_code}')
# Out:
# Título da página: Cofecon realiza oficina sobre inteligência artificial para economistas – Conselho Federal de Economia – COFECON
# Link encontrado: http://cofecon.org.br/comissoes/
# Link encontrado: https://portalsei.cofecon.org/
# Link encontrado: http://cofecon.org.br/transpini/
# Link encontrado: #
# Link encontrado: https://apps.thomasgreg.com.br/SP/cofecon/WEB/Usuario/Login
# Link encontrado: https://play.google.com/store/apps/details?id=br.com.thomasgreg.carteira_digital.cofecon
# Link encontrado: https://apps.apple.com/app/carteira-digital-cofecon/id6502531981
# Link encontrado: tel:+556132081800
# Link encontrado: https://www.facebook.com/cofeconeconomia/
# Link encontrado: https://twitter.com/cofeconeconomia
# Link encontrado: https://www.youtube.com/channel/UCFe-Ax_n_mUJSx6Xng8y0WA
# Link encontrado: https://www.instagram.com/cofecon/?hl=pt-br
# Link encontrado: skype:cofecon?call
# ...
